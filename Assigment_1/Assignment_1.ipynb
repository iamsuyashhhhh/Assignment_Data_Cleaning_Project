# %%
import pandas as pd

# %%
df = pd.read_csv("Combined_dataset.csv")

# %%
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# ...

# %%
df.tail()
# Out:
#      product_id     title                                product_description  \
# 995    13698258     KREDO  Men FORTE Silver Automatic Skeleton Analogue W...
# 996    16896006     GUESS  Women White Patterned Dial & White Straps Anal...
# 997     1708108  GIORDANO  Women Rose Gold-Toned Mirrored Analogue Watch ...
# 998    19280114  Fastrack  Men Black Brass Dial & Black Stainless Steel S...
# 999    18601682   BOLDFIT                           Purple Textured Yoga Mat
#
#      rating  ratings_count  initial_price  discount   final_price currency  \
# 995     3.5             11          11890      50.0  "₹11,890.00"      INR
# 996     5.0             22           8900      45.0   "₹8,900.00"      INR
# 997     2.8              5           7950      50.0   "₹7,950.00"      INR
# 998     4.3             17           3295      20.0   "₹2,636.00"      INR
# 999     3.8            161            699      31.0     "₹699.00"      INR
#
# ...

# %%
df.shape
# Out:
# (1000, 24)

# %%
df.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='str')

# %%
df.dtypes
# Out:
# product_id                  int64
# title                         str
# product_description           str
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price                   str
# currency                      str
# images                        str
# delivery_options              str
# product_details               str
# breadcrumbs                   str
# product_specifications        str
# amount_of_stars               str
# what_customers_said           str
# seller_name                   str
# sizes                         str
# videos                        str
# seller_information            str
# variations                    str
# best_offer                    str
# more_offers                   str
# category                      str
# dtype: object

# %%
df.isnull().sum()
# Out:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                  121
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %%
df["discount"] = df["discount"].fillna(df["discount"].mean())

# %%
df["what_customers_said"] = df["what_customers_said"].fillna("No Review")

# %%
df["seller_name"] = df["seller_name"].fillna("Unknown")

# %%
df["videos"] = df["videos"].fillna("No Video")

# %%
df["seller_information"] = df["seller_information"].fillna("Unavailable")

# %%
df["variations"] = df["variations"].fillna("No Variations")

# %%
df.isnull().sum()
# Out:
# product_id                0
# title                     0
# product_description       0
# rating                    0
# ratings_count             0
# initial_price             0
# discount                  0
# final_price               0
# currency                  0
# images                    0
# delivery_options          0
# product_details           0
# breadcrumbs               0
# product_specifications    0
# amount_of_stars           0
# what_customers_said       0
# seller_name               0
# sizes                     0
# videos                    0
# seller_information        0
# variations                0
# best_offer                0
# more_offers               0
# category                  0
# dtype: int64

# %%
df[["title", "category", "final_price", "rating"]]
# Out:
#               title   category   final_price  rating
# 0       Lino Perros  backpacks   "₹3,995.00"     3.8
# 1    Tommy Hilfiger  backpacks   "₹2,899.00"     4.5
# 2             Lavie  backpacks   "₹2,999.00"     4.4
# 3            F Gear  backpacks   "₹1,675.00"     4.4
# 4         MYTRIDENT  bath-robe   "₹2,899.00"     4.7
# ..              ...        ...           ...     ...
# 995           KREDO    watches  "₹11,890.00"     3.5
# 996           GUESS    watches   "₹8,900.00"     5.0
# 997        GIORDANO    watches   "₹7,950.00"     2.8
# 998        Fastrack    watches   "₹2,636.00"     4.3
# 999         BOLDFIT  yoga-mats     "₹699.00"     3.8
#
# [1000 rows x 4 columns]

# %%
df[df["rating"] > 4]
# Out:
#      product_id              title  \
# 1       9136281     Tommy Hilfiger
# 2      17633752              Lavie
# 3       1376949             F Gear
# 4      13939916          MYTRIDENT
# 5      17198778                H&M
# ..          ...                ...
# 991     2466414       Daniel Klein
# 992    11791782              CASIO
# 994     8481603  French Connection
# 996    16896006              GUESS
# 998    19280114           Fastrack
#
#                                    product_description  rating  ratings_count  \
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# 5           Beige & Tan Solid Stoneware Soap Dispenser     4.5             42
# ...

# %%
df["category"].unique()
# Out:
# <StringArray>
# [              'backpacks',               'bath-robe',
#     'bathroom-accessories',             'bath-towels',
#                'bedsheets',                   'belts',
#                 'bodysuit',                   'boots',
#                   'boxers',                     'bra',
#                 'bracelet',                  'briefs',
#                'camisoles',          'candle-holders',
#                     'caps',            'casual-shoes',
#              'chair-cover',            'clothing-set',
#                 'clutches',                 'co-ords',
#      'curtains-and-sheers',                 'cutlery',
#               'dinnerware',                 'dresses',
#               'duffel-bag',               'dungarees',
#                  'dupatta',                'earrings',
#           'ethnic-dresses',       'face-moisturisers',
#   'face-wash-and-cleanser',                   'flats',
#               'flip-flops',    'floor-mats--dhurries',
# ...

# %%
df[df["category"] == "jeans"]
# Out:
#      product_id                      title  \
# 374    18973692                      Levis
# 375    18973742                      Levis
# 376    19008522         Calvin Klein Jeans
# 377    18974084                      Levis
# 378    18873126                      KETCH
# 379    18826658                  Chemistry
# 380    18960426                        Lee
# 381    18802522  BEAT LONDON by PEPE JEANS
# 382    18973648                      Levis
# 383    18973888                      Levis
# 384    18973730                      Levis
# 385    18973948                      Levis
# 386    19008496         Calvin Klein Jeans
# 387    18873142                      KETCH
# 388    18992754  AMERICAN EAGLE OUTFITTERS
# 389    18973922                      Levis
# 390    18979610                 KiddoPanti
# 391    18675392               Jack & Jones
# 392    18973950                      Levis
# 393    18198558                 FOREVER 21
# 394    18094702                   Roadster
# ...

# %%
df[df["category"] == "handbags"]
# Out:
#      product_id         title  \
# 312    21421856        Baggit
# 313    21421918        Baggit
# 314    16696848   Accessorize
# 315    21232798       ESTALON
# 316    18200086       Caprese
# 317     7743536   Lino Perros
# 318     7743355   Lino Perros
# 319     8293015   Lychee bags
# 320    17637810      Toteteca
# 321    17761230       Caprese
# 322    15188034         Metro
# 323    21762808        Baggit
# 324    21421996        Baggit
# 325    21621752     Berrylush
# 326    13359482  FLYING BERRY
# 327    13389422  DailyObjects
# 328    13389410  DailyObjects
# 329    22603262  DailyObjects
#
#                                    product_description  rating  ratings_count  \
# 312  Dinosaur Textured PU Regular Structured Handhe...     4.4              5
# 313                              Textured Handheld Bag     4.6             18
# 314          London Women Faux Leather Piper Sling bag     4.6             38
# ...

# %%
df.sort_values(by="final_price")
# Out:
#      product_id              title  \
# 525    17292364             Mitera
# 665    19024468        Blackberrys
# 532    16287654         Saree mall
# 929    10019547               XYXX
# 248    22411344            Juniper
# ..          ...                ...
# 69     13638220             FAUSTO
# 817    18478530          Paralians
# 808    20405594             AAHWAN
# 201    20195790     Dupatta Bazaar
# 870    17938374  CODE by Lifestyle
#
#                                    product_description  rating  ratings_count  \
# 525   Mustard & Gold-Toned Striped Zari Leheriya Saree     4.0             18
# 665            Men Pure Cotton Printed Slim Fit Shorts     4.1              9
# 532        Navy Blue Floral Linen Blend Banarasi Saree     4.1            359
# 929  Men IntelliSoft Antimicrobial Micro Modal Pack...     4.7              9
# 248        Floral Embroidered Flared Cotton Midi Dress     3.9             11
# ...

# %%
df = df.drop_duplicates()

# %%
df["quantity"] = 1

# %%
df["total_amount"] = df["final_price"] * df["quantity"]

# %%
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ... seller_name  \
# ...

# %%
df.to_csv("cleaned_dataset.csv", index=False)
